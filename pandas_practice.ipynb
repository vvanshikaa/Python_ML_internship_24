# %%
import numpy as np
import pandas as pd

# %%
dic={
    "Name":["Ram", "Shyam", "Sameer", "Kajal", "Irfan", "Riya"],
    "Roll no":[1,2,3,4,5,6],
    "Grades":["A","B","C","A","B","A"],
    "Email":["abc@xyz.com", "def@abc.com", "igh@def.com", "lmn@opq.com", "rsj@omn.com", "bgm@kyf.com"]
}
dic
# Out:
# {'Name': ['Ram', 'Shyam', 'Sameer', 'Kajal', 'Irfan', 'Riya'],
#  'Roll no': [1, 2, 3, 4, 5, 6],
#  'Grades': ['A', 'B', 'C', 'A', 'B', 'A'],
#  'Email': ['abc@xyz.com',
#   'def@abc.com',
#   'igh@def.com',
#   'lmn@opq.com',
#   'rsj@omn.com',
#   'bgm@kyf.com']}

# %%
df = pd.DataFrame(dic)
df
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@abc.com
# 2  Sameer        3      C  igh@def.com
# 3   Kajal        4      A  lmn@opq.com
# 4   Irfan        5      B  rsj@omn.com
# 5    Riya        6      A  bgm@kyf.com

# %%
df.head(2)
# Out:
#     Name  Roll no Grades        Email
# 0    Ram        1      A  abc@xyz.com
# 1  Shyam        2      B  def@abc.com

# %%
df.tail(3)
# Out:
#     Name  Roll no Grades        Email
# 3  Kajal        4      A  lmn@opq.com
# 4  Irfan        5      B  rsj@omn.com
# 5   Riya        6      A  bgm@kyf.com

# %%
df.describe()
# Out:
#         Roll no
# count  6.000000
# mean   3.500000
# std    1.870829
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    6.000000

# %%
import numpy as np
import pandas as pd
cus = pd.read_csv('customer.csv')
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
type(cus)
# Out:
# pandas.core.frame.DataFrame

# %%
type(cus['CustomerID'])
# Out:
# pandas.core.series.Series

# %%
cus.index
# Out:
# RangeIndex(start=0, stop=91, step=1)

# %%
cus.columns
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy()
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus.T
# Out:
#                                 0                                   1   \
# CustomerID                       1                                   2
# Company Name   Alfreds Futterkiste  Ana Trujillo Emparedados y helados
# Costumer Name         Maria Anders                        Ana Trujillo
# City                        Berlin                         Mexico D.F.
# PostalCode                   12209                                5021
# Country                    Germany                              Mexico
#
#                                     2                3                   4   \
# CustomerID                           3                4                   5
# Company Name   Antonio Moreno Taqueria  Around the Horn   Berglunds snabbkp
# Costumer Name           Antonio Moreno     Thomas Hardy  Christina Berglund
# City                       Mexico D.F.           London               Lulea
# PostalCode                        5023            34626               95822
# ...

# %%
cus.drop(0)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 1   Mexico D.F.        5021   Mexico
# 2   Mexico D.F.        5023   Mexico
# ...

# %%
cus.drop(3)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
import numpy as np
import pandas as pd
cus = pd.read_csv('customer.csv')

cus.loc[(48,78),('Company Name','Costumer Name')]
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 78            Toms Spezialitaten     Karin Josephs

# %%
np.array(cus.loc[:,'Company Name'])
# Out:
# array(['Alfreds Futterkiste', 'Ana Trujillo Emparedados y helados',
#        'Antonio Moreno Taqueria', 'Around the Horn', 'Berglunds snabbkp',
#        'Blauer See Delikatessen', 'Blondel pere et fils',
#        'BOlido Comidas preparadas', 'Bon app', 'Bottom-Dollar Marketse',
#        'Bs Beverages', 'Cactus Comidas para llevar',
#        'Centro comercial Moctezuma', 'Chop-suey Chinese',
#        'Comercio Mineiro', 'Consolidated Holdings',
#        'Drachenblut Delikatessend', 'Du monde entier',
#        'Eastern Connection', 'Ernst Handel', 'Familia Arquibaldo',
#        'FISSA Fabrica Inter. Salchichas S.A.', 'Folies gourmandes',
#        'Folk och fa HB', 'Frankenversand', 'France restauration',
#        'Franchi S.p.A.', 'Furia Bacalhau e Frutos do Mar',
#        'Galeria del gastrOnomo', 'Godos Cocina Tipica',
#        'Gourmet Lanchonetes', 'Great Lakes Food Market',
#        'GROSELLA-Restaurante', 'Hanari Carnes', 'HILARION-Abastos',
# ...

# %%
CN=cus.loc[:,'Company Name']
CN
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
employees = [
    {"company": "TechCorp", "employee": "Alice Johnson", "position": "Software Engineer"},
    {"company": "InnovateX", "employee": "Bob Smith", "position": "Data Scientist"},
    {"company": "HealthPlus", "employee": "Carol White", "position": "Project Manager"},
    {"company": "GreenEnergy", "employee": "David Brown", "position": "Electrical Engineer"},
    {"company": "EduSmart", "employee": "Eve Davis", "position": "Curriculum Developer"},
    {"company": "FinSecure", "employee": "Frank Harris", "position": "Financial Analyst"},
    {"company": "AutoDrive", "employee": "Grace Lee", "position": "Mechanical Engineer"},
    {"company": "BuildRight", "employee": "Henry Wilson", "position": "Architect"},
    {"company": "MediCare", "employee": "Ivy Martinez", "position": "Nurse Practitioner"},
    {"company": "FarmFresh", "employee": "Jack Robinson", "position": "Agricultural Scientist"},
    {"company": "BrightFuture", "employee": "Kate Walker", "position": "HR Manager"},
    {"company": "CloudNet", "employee": "Liam Young", "position": "Network Engineer"},
    {"company": "TravelEase", "employee": "Mia King", "position": "Travel Consultant"},
    {"company": "SafeGuard", "employee": "Noah Scott", "position": "Security Analyst"},
    {"company": "QuickFix", "employee": "Olivia Moore", "position": "Customer Support Specialist"},
    {"company": "HealthyLife", "employee": "Paul Adams", "position": "Nutritionist"},
    {"company": "TechNova", "employee": "Quincy Baker", "position": "DevOps Engineer"},
    {"company": "EconoMart", "employee": "Rachel Green", "position": "Store Manager"},
    {"company": "UrbanDev", "employee": "Sam Carter", "position": "Urban Planner"},
    {"company": "MediaBuzz", "employee": "Tina Rogers", "position": "Content Writer"},
    {"company": "GameWorld", "employee": "Uma Sanchez", "position": "Game Developer"},
    {"company": "FreshFoods", "employee": "Victor Reed", "position": "Chef"},
    {"company": "SolarBright", "employee": "Wendy Cook", "position": "Solar Technician"},
    {"company": "FitWell", "employee": "Xavier Bell", "position": "Fitness Trainer"},
    {"company": "SmartTech", "employee": "Yara Murphy", "position": "IT Support Specialist"},
    {"company": "AquaPure", "employee": "Zachary Russell", "position": "Water Quality Engineer"},
    {"company": "GreenThumb", "employee": "Aiden Coleman", "position": "Landscape Designer"},
    {"company": "BrightMinds", "employee": "Brooke Hayes", "position": "Educational Consultant"},
    {"company": "MoveFast", "employee": "Caleb Jenkins", "position": "Logistics Manager"},
    {"company": "SoundWave", "employee": "Diana Perez", "position": "Audio Engineer"},
    {"company": "StyleHouse", "employee": "Ethan Kelly", "position": "Fashion Designer"},
    {"company": "BuildStrong", "employee": "Fiona Brooks", "position": "Construction Manager"},
    {"company": "PureHealth", "employee": "Gavin Powell", "position": "Pharmacist"},
    {"company": "TechGear", "employee": "Hannah Foster", "position": "Product Manager"},
    {"company": "SkyHigh", "employee": "Isaac Barnes", "position": "Aerospace Engineer"},
    {"company": "PlayTime", "employee": "Jade Kim", "position": "Toy Designer"},
    {"company": "CleanSweep", "employee": "Kyle Ortiz", "position": "Janitorial Supervisor"},
    {"company": "BioGen", "employee": "Lila Murray", "position": "Biochemist"},
    {"company": "AutoMotive", "employee": "Mason Daniels", "position": "Auto Mechanic"},
    {"company": "SmartHome", "employee": "Nina Foster", "position": "Home Automation Specialist"},
    {"company": "DataInsight", "employee": "Oscar Hayes", "position": "Data Analyst"},
    {"company": "MegaStore", "employee": "Paula Carter", "position": "Retail Sales Associate"},
    {"company": "BrightPath", "employee": "Quinton Price", "position": "Career Counselor"},
    {"company": "HealthWave", "employee": "Riley Jenkins", "position": "Physical Therapist"},
    {"company": "FoodieHaven", "employee": "Sophia Mitchell", "position": "Pastry Chef"},
    {"company": "EcoSolutions", "employee": "Tyler James", "position": "Environmental Scientist"},
    {"company": "BrightLights", "employee": "Ursula Reed", "position": "Lighting Technician"},
    {"company": "StyleElite", "employee": "Victoria Grant", "position": "Stylist"},
    {"company": "TechSavvy", "employee": "William Gray", "position": "Systems Administrator"}
]
employees
# Out:
# [{'company': 'TechCorp',
#   'employee': 'Alice Johnson',
#   'position': 'Software Engineer'},
#  {'company': 'InnovateX',
#   'employee': 'Bob Smith',
#   'position': 'Data Scientist'},
#  {'company': 'HealthPlus',
#   'employee': 'Carol White',
#   'position': 'Project Manager'},
#  {'company': 'GreenEnergy',
#   'employee': 'David Brown',
#   'position': 'Electrical Engineer'},
#  {'company': 'EduSmart',
#   'employee': 'Eve Davis',
#   'position': 'Curriculum Developer'},
#  {'company': 'FinSecure',
#   'employee': 'Frank Harris',
#   'position': 'Financial Analyst'},
#  {'company': 'AutoDrive',
#   'employee': 'Grace Lee',
#   'position': 'Mechanical Engineer'},
#  {'company': 'BuildRight',
#   'employee': 'Henry Wilson',
#   'position': 'Architect'},
#  {'company': 'MediCare',
#   'employee': 'Ivy Martinez',
#   'position': 'Nurse Practitioner'},
#  {'company': 'FarmFresh',
#   'employee': 'Jack Robinson',
#   'position': 'Agricultural Scientist'},
# ...

# %%
cd = pd.DataFrame(employees)
cd
# Out:
#          company         employee                     position
# 0       TechCorp    Alice Johnson            Software Engineer
# 1      InnovateX        Bob Smith               Data Scientist
# 2     HealthPlus      Carol White              Project Manager
# 3    GreenEnergy      David Brown          Electrical Engineer
# 4       EduSmart        Eve Davis         Curriculum Developer
# 5      FinSecure     Frank Harris            Financial Analyst
# 6      AutoDrive        Grace Lee          Mechanical Engineer
# 7     BuildRight     Henry Wilson                    Architect
# 8       MediCare     Ivy Martinez           Nurse Practitioner
# 9      FarmFresh    Jack Robinson       Agricultural Scientist
# 10  BrightFuture      Kate Walker                   HR Manager
# 11      CloudNet       Liam Young             Network Engineer
# 12    TravelEase         Mia King            Travel Consultant
# 13     SafeGuard       Noah Scott             Security Analyst
# ...

# %%
cd.T
# Out:
#                          0               1                2   \
# company            TechCorp       InnovateX       HealthPlus
# employee      Alice Johnson       Bob Smith      Carol White
# position  Software Engineer  Data Scientist  Project Manager
#
#                            3                     4                  5   \
# company           GreenEnergy              EduSmart          FinSecure
# employee          David Brown             Eve Davis       Frank Harris
# position  Electrical Engineer  Curriculum Developer  Financial Analyst
#
#                            6             7                   8   \
# company             AutoDrive    BuildRight            MediCare
# employee            Grace Lee  Henry Wilson        Ivy Martinez
# position  Mechanical Engineer     Architect  Nurse Practitioner
#
#                               9   ...                          39  \
# company                FarmFresh  ...                   SmartHome
# ...

# %%
cd.drop_duplicates(subset='company',keep=False)
# Out:
#          company         employee                     position
# 0       TechCorp    Alice Johnson            Software Engineer
# 1      InnovateX        Bob Smith               Data Scientist
# 2     HealthPlus      Carol White              Project Manager
# 3    GreenEnergy      David Brown          Electrical Engineer
# 4       EduSmart        Eve Davis         Curriculum Developer
# 5      FinSecure     Frank Harris            Financial Analyst
# 6      AutoDrive        Grace Lee          Mechanical Engineer
# 7     BuildRight     Henry Wilson                    Architect
# 8       MediCare     Ivy Martinez           Nurse Practitioner
# 9      FarmFresh    Jack Robinson       Agricultural Scientist
# 10  BrightFuture      Kate Walker                   HR Manager
# 11      CloudNet       Liam Young             Network Engineer
# 12    TravelEase         Mia King            Travel Consultant
# 13     SafeGuard       Noah Scott             Security Analyst
# ...
